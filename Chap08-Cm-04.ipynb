# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso

url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'

auto = pd.read_csv(url, header=None)

auto.columns = [
    'symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
    'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
    'wheel-base', 'length', 'width', 'height', 'curb-weight',
    'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system',
    'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm',
    'city-mpg', 'highway-mpg', 'price'
]

# 練習問題8-1と同じデータを使う
auto = auto[['price', 'width', 'engine-size']]

# 欠損値処理
auto = auto.replace('?', np.nan)
auto = auto.dropna()

# 数値型に変換
auto['price'] = pd.to_numeric(auto['price'])
auto['width'] = pd.to_numeric(auto['width'])
auto['engine-size'] = pd.to_numeric(auto['engine-size'])

auto.head()

# 説明変数と目的変数
X = auto[['width', 'engine-size']]
y = auto['price']

# 訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.5,
    random_state=0
)

# ラッソ回帰
lasso = Lasso(alpha=1.0, max_iter=10000)

# 学習
lasso.fit(X_train, y_train)

# 評価
print('Lasso train score:', lasso.score(X_train, y_train))
print('Lasso test score:', lasso.score(X_test, y_test))

# 係数と切片
print('係数')
print(pd.Series(lasso.coef_, index=X.columns))

print('切片:', lasso.intercept_)
# Out:
# Lasso train score: 0.7831885934802829
# Lasso test score: 0.7783078443030256
# 係数
# width          1261.377493
# engine-size     109.541760
# dtype: float64
# 切片: -84038.9642957416
