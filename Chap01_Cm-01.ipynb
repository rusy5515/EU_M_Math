# %% [markdown]
# ### 宇宙航空数学特論　第四回課題　2026/04/27

# %%
print("Hello, World!")
print(1+1)
print(2*5)
print(10**3)
# Out:
# Hello, World!
# 2
# 10
# 1000

# %%
1==2
# Out:
# False

# %%
print("{0}と{1}を足すと{2}になります。".format(2,3,5))
# Out:
# 2と3を足すと5になります。

# %%
for n in range(2, 11):
    is_prime = True

    for i in range(2, n):
        if n % i == 0:
            is_prime = False
        
    if is_prime == True:
        print(n)
# Out:
# 2
# 3
# 5
# 7
