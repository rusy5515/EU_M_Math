# %%
# 練習問題 5-16
import numpy as np
from scipy import integrate

answer_5_16 = integrate.quad(lambda x: np.cos(x), 0, np.pi)

print("answer_5_16 積分値:", answer_5_16[0])
print("answer_5_16 推定誤差:", answer_5_16[1])
