# %% [markdown]
# 以下の関数が0となる解を、ニュートン法を用いて求めろ。
# f(x) = x^3+2x+1

# %%
from scipy.optimize import newton

def my_function(x):
    return x**3 + 2*x + 1

print(newton(my_function, 0))
# Out:
# -0.45339765151640365
