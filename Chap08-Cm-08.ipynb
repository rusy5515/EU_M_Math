# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# SVMでは標準化したデータを使う
sc = StandardScaler()

sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# SVCモデル
svm_model = SVC(
    kernel='rbf',
    C=2,
    random_state=0
)

# 学習
svm_model.fit(X_train_std, y_train)

# スコア確認
print('正解率(train): {:.3f}'.format(svm_model.score(X_train_std, y_train)))
print('正解率(test): {:.3f}'.format(svm_model.score(X_test_std, y_test)))

svm_no_scale = SVC(
    kernel='rbf',
    C=2,
    random_state=0
)

svm_no_scale.fit(X_train, y_train)

print('標準化なし 正解率(train): {:.3f}'.format(svm_no_scale.score(X_train, y_train)))
print('標準化なし 正解率(test): {:.3f}'.format(svm_no_scale.score(X_test, y_test)))
