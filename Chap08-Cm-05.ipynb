# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# 決定木モデル
tree = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=5,
    random_state=0
)

# 学習
tree.fit(X_train, y_train)

# スコア確認
print('正解率(train): {:.3f}'.format(tree.score(X_train, y_train)))
print('正解率(test): {:.3f}'.format(tree.score(X_test, y_test)))

depth_list = [1, 2, 3, 4, 5, 6, 10, None]

results = []

for depth in depth_list:
    tree = DecisionTreeClassifier(
        criterion='entropy',
        max_depth=depth,
        random_state=0
    )
    
    tree.fit(X_train, y_train)
    
    results.append({
        'max_depth': depth,
        'train_score': tree.score(X_train, y_train),
        'test_score': tree.score(X_test, y_test),
        'actual_depth': tree.get_depth()
    })

result_tree = pd.DataFrame(results)
result_tree

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# ランダムフォレストモデル
forest = RandomForestClassifier(
    n_estimators=100,
    random_state=0
)

# 学習
forest.fit(X_train, y_train)

# スコア確認
print('正解率(train): {:.3f}'.format(forest.score(X_train, y_train)))
print('正解率(test): {:.3f}'.format(forest.score(X_test, y_test)))

forest_depth = RandomForestClassifier(
    n_estimators=100,
    max_depth=5,
    random_state=0
)

forest_depth.fit(X_train, y_train)

print('正解率(train): {:.3f}'.format(forest_depth.score(X_train, y_train)))
print('正解率(test): {:.3f}'.format(forest_depth.score(X_test, y_test)))
