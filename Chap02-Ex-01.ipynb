# %% [markdown]
# 1から50までの自然数の輪を計算するプログラムを書いて、最後に計算結果を表示するプログラムをかけ。np.arrayで1から50までの配列を作り、その総和を求める方法で計算。

# %%
import numpy as np

numbers = np.array(range(1,51))
total = np.sum(numbers)

print(total)
# Out:
# 1275
