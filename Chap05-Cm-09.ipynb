# %% [markdown]
# 次のリストに対して、各要素に3を足した配列を作りなさい。

# %%
import numpy as np

sample_list = [1, 2, 3, 4, 5]
sample_array = np.array(sample_list) + 3
print("sample_list")
print(sample_list)
print("sample_array")
print(sample_array)
# Out:
# sample_list
# [1, 2, 3, 4, 5]
# sample_array
# [4 5 6 7 8]
